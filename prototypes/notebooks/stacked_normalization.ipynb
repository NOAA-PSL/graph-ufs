# %%
import os
import numpy as np
from omegaconf import OmegaConf
import xarray as xr
from prototypes.ocn_only.emulator import OcnTrainer

# %%
prototype = "R4"

# %%
config_trainer_path = f"../ocn_only/{prototype}/config.yaml"
trainer_config = OmegaConf.load(config_trainer_path)
emulator = OcnTrainer(config=trainer_config)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 config_trainer_path = f"../ocn_only/{prototype}/config.yaml"
#       2 trainer_config = OmegaConf.load(config_trainer_path)
# ----> 3 emulator = OcnTrainer(config=trainer_config)
#
# File ~/graph-ufs/prototypes/ocn_only/emulator.py:137, in OcnTrainer.__init__(self, config, mpi_rank, mpi_size)
#     134 else:
#     135     self.writer = None
# --> 137 super().__init__(mpi_rank=mpi_rank, mpi_size=mpi_size)
#
# File ~/graph-ufs/graphufs/fvcoupledemulator.py:114, in FVCoupledEmulator.__init__(self, mpi_rank, mpi_size)
#     112 self.stacked_norm = dict()
#     113 self.set_normalization()
# --> 114 self.set_stacked_normalization()
#     116 # TOA Incident Solar Radiation integration period
#     117 if self.tisr_integration_period is None:
#
# File ~/graph-ufs/graphufs/coupledemulator.py:1027, in ReplayCoupledEmulator.set_stacked_normalization(self)
#    1025 for key in self.norm.keys():
#    1026     self.stacked_norm[key] = dict()
# -> 1027     input_norms, target_norms = open_normalization(key)
#    1028     self.stacked_norm[key] = {"inputs": input_norms, "targets": target_norms}
#
# File ~/graph-ufs/graphufs/coupledemulator.py:1017, in ReplayCoupledEmulator.set_stacked_normalization.<locals>.open_normalization(moment)
#    1014     targets = targets["targets"].load()
#    1016 else:
# -> 1017     inputs, targets = self.normalization_to_stacked(self.norm[moment], preserved_dims=tuple())
#    1018     ds = xr.Dataset()
#    1019     inputs = inputs.load()
#
# File ~/graph-ufs/graphufs/coupledemulator.py:1053, in ReplayCoupledEmulator.normalization_to_stacked(self, xds, **kwargs)
#    1050     norms = norms.transpose(*dimorder)
#    1051     return dataset_to_stacked(norms, **kwargs)
# -> 1053 input_norms = stackit(xds, self.input_variables, n_time=self.n_input, **kwargs)
#    1054 forcing_norms = stackit(xds, self.forcing_variables, n_time=self.n_target, **kwargs)
#    1055 target_norms = stackit(xds, self.target_variables, n_time=self.n_target, **kwargs)
#
# File ~/graph-ufs/graphufs/coupledemulator.py:1050, in ReplayCoupledEmulator.normalization_to_stacked.<locals>.stackit(xds, varnames, n_time, **kwargs)
#    1048     dimorder = ("batch", "time", "level", "lat", "lon")
#    1049 dimorder = tuple(x for x in dimorder if x in norms.dims)
# -> 1050 norms = norms.transpose(*dimorder)
#    1051 return dataset_to_stacked(norms, **kwargs)
#
# File ~/.conda/envs/graphufs-mpi/lib/python3.11/site-packages/xarray/util/deprecation_helpers.py:143, in deprecate_dims.<locals>.wrapper(*args, **kwargs)
#     135     emit_user_level_warning(
#     136         f"The `{old_name}` argument has been renamed to `dim`, and will be removed "
#     137         "in the future. This renaming is taking place throughout xarray over the "
#    (...)
#     140         PendingDeprecationWarning,
#     141     )
#     142     kwargs["dim"] = kwargs.pop(old_name)
# --> 143 return func(*args, **kwargs)
#
# File ~/.conda/envs/graphufs-mpi/lib/python3.11/site-packages/xarray/core/dataset.py:6479, in Dataset.transpose(self, missing_dims, *dim)
#    6477 # Use infix_dims to check once for missing dimensions
#    6478 if len(dim) != 0:
# -> 6479     _ = list(infix_dims(dim, self.dims, missing_dims))
#    6481 ds = self.copy()
#    6482 for name, var in self._variables.items():
#
# File ~/.conda/envs/graphufs-mpi/lib/python3.11/site-packages/xarray/namedarray/utils.py:173, in infix_dims(dims_supplied, dims_all, missing_dims)
#     171 existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
#     172 if set(existing_dims) ^ set(dims_all):
# --> 173     raise ValueError(
#     174         f"{dims_supplied} must be a permuted list of {dims_all}, unless `...` is included"
#     175     )
#     176 yield from existing_dims
#
# ValueError: ('time', 'level', 'z_l', 'lat', 'lon') must be a permuted list of FrozenMappingWarningOnValuesAccess({'time': 1, 'lat': 192, 'lon': 384, 'z_l': 7, 'grid_xt': 384, 'grid_yt': 192, 'level': 1}), unless `...` is included
