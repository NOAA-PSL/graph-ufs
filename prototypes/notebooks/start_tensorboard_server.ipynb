# %%
#import tensorflow as tf
import nersc_tensorboard_helper

### To run tensorboard in Jupyter you first import the extension
# %load_ext tensorboard

# %%
### Now you can run a tensorboard server. Note that port 0 asks tensorboard to use a port not already in use
# %tensorboard --logdir /pscratch/sd/n/nagarwal/ocn-only/R2/tensorboard/ --port 0
# Out:
#       <iframe id="tensorboard-frame-f4ed7b5ce96750dc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f4ed7b5ce96750dc");
#           const url = new URL("/", window.location);
#           const port = 43381;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
### The following function will provide you with an address to connect to the tensorboard instance
nersc_tensorboard_helper.tb_address()
# Out:
# <a href="https://jupyter.nersc.gov/user/nagarwal/perlmutter-exclusive-node-cpu/proxy/43381/">https://jupyter.nersc.gov/user/nagarwal/perlmutter-exclusive-node-cpu/proxy/43381/</a>
