# %%
from config import CP1Trainer
from graphufs.datasets import Dataset

# %%
gufs = CP1Trainer()
# Out:
# myvars after renaming: ['vgrd', 'uo', 'icec', 'so', 'icetk', 'soilt1', 'pressfc', 'temp', 'log_spfh', 'year_progress_sin', 'SSH', 'day_progress_sin', 'tmpsfc', 'log_spfh2m', 'ugrd10m', 'dzdt', 'dswrf_avetoa', 'tmp2m', 'SW', 'soilm', 'ugrd', 'vgrd10m', 'day_progress_cos', 'vo', 'tmp', 'LW', 'year_progress_cos']
# myvars after renaming: ['vgrd', 'uo', 'icec', 'so', 'icetk', 'soilt1', 'pressfc', 'temp', 'log_spfh', 'year_progress_sin', 'SSH', 'day_progress_sin', 'tmpsfc', 'log_spfh2m', 'ugrd10m', 'dzdt', 'dswrf_avetoa', 'tmp2m', 'SW', 'soilm', 'ugrd', 'vgrd10m', 'day_progress_cos', 'vo', 'tmp', 'LW', 'year_progress_cos']
# myvars after renaming: ['vgrd', 'uo', 'icec', 'so', 'icetk', 'soilt1', 'pressfc', 'temp', 'log_spfh', 'year_progress_sin', 'SSH', 'day_progress_sin', 'tmpsfc', 'log_spfh2m', 'ugrd10m', 'dzdt', 'dswrf_avetoa', 'tmp2m', 'SW', 'soilm', 'ugrd', 'vgrd10m', 'day_progress_cos', 'vo', 'tmp', 'LW', 'year_progress_cos']

# %%
tds = Dataset(gufs, mode="training")

# %%
x,y = tds[0]
# Out:
# Sample extracted: <xarray.Dataset> Size: 154MB
# Dimensions:       (time: 3, lat: 192, lon: 384, level: 16, z_l: 10, z_i: 11)
# Coordinates:
#   * level         (level) float64 128B 226.1 277.8 327.7 ... 874.7 922.6 974.3
#   * lon           (lon) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#   * lat           (lat) float64 2kB 89.82 88.89 87.95 ... -87.25 -88.18 -89.12
#     datetime      (time) datetime64[ns] 24B 1993-12-31T18:00:00 ... 1994-01-0...
#   * z_i           (z_i) float64 88B 0.0 1.031 4.498 10.8 ... 190.2 352.3 483.1
#   * z_l           (z_l) float64 80B 0.5154 2.765 7.648 ... 152.1 271.2 417.7
#   * time          (time) timedelta64[ns] 24B 00:00:00 06:00:00 12:00:00
# Data variables: (12/25)
#     ugrd10m       (time, lat, lon) float32 885kB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
#     dzdt          (time, level, lat, lon) float32 14MB dask.array<chunksize=(1, 16, 192, 384), meta=np.ndarray>
# ...

# %%
x
# Out:
# <xarray.DataArray (batch: 1, lat: 192, lon: 384, channels: 281)> Size: 166MB
# dask.array<concatenate, shape=(1, 192, 384, 281), dtype=float64, chunksize=(1, 192, 384, 16), chunktype=numpy.ndarray>
# Coordinates:
#   * batch    (batch) int64 8B 0
#   * lon      (lon) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#   * lat      (lat) float64 2kB 89.82 88.89 87.95 87.01 ... -87.25 -88.18 -89.12
# Dimensions without coordinates: channels
# Attributes:
#     long_name:      Longwave radiation flux into ocean
#     regrid_method:  conservative
#     units:          W m-2

# %%
y
# Out:
# <xarray.DataArray (batch: 1, lat: 192, lon: 384, channels: 133)> Size: 78MB
# dask.array<concatenate, shape=(1, 192, 384, 133), dtype=float64, chunksize=(1, 192, 384, 16), chunktype=numpy.ndarray>
# Coordinates:
#   * batch    (batch) int64 8B 0
#   * lon      (lon) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#   * lat      (lat) float64 2kB 89.82 88.89 87.95 87.01 ... -87.25 -88.18 -89.12
# Dimensions without coordinates: channels
# Attributes:
#     long_name:      Longwave radiation flux into ocean
#     regrid_method:  conservative
#     units:          W m-2
